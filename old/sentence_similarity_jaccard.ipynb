# %%
import pandas as pd
import bareunpy

# %%
df_old = pd.read_excel('data/ASIS_발화데이터.xlsx')

# %%
df_old.head()
# Out:
#        INTENT                   SENTENCE
# 0  100퍼센트충전안됨        배터리 아무리 해도 백이 되지 않음
# 1  100퍼센트충전안됨  배터리가 구십퍼 이상으로 충전이 되지 않습니다
# 2  100퍼센트충전안됨               백퍼로 충전이 안 돼요
# 3  100퍼센트충전안됨             오래 충전해도 완충 안 됨
# 4  100퍼센트충전안됨         배터리가 백퍼센트 충전이 안 돼요

# %%
df_new = pd.read_excel('data/TOBE_제품확대.xlsx')

# %%
df_new.head()
# Out:
#        INTENT              SENTENCE
# 0       E1 에러          이원 버그 표시 뭐예요
# 1       E1 에러           이원에러 표시 떳어요
# 2  FdH표시_하칸제상     냉장고 에프 디 에이치 에러코드
# 3  FdH표시_하칸제상  냉장고 에프 디 에이치 오류가 있어요
# 4  FdH표시_하칸제상      냉장고 에프 디 에이치가 떠요

# %%
df_old.shape, df_new.shape
# Out:
# ((55530, 2), (677, 2))

# %%
apikey = 'koba-6HVXOFQ-OYBELVA-VAAS3JY-D3XGLBY'
tagger = bareunpy.Tagger(apikey, 'localhost')

# %%
def jacaard_similarity(listA, listB):
    s1 = set(listA)
    s2 = set(listB)
    
    return float(len(s1.intersection(s2)) / len(s1.union(s2)))

# %%
# 형태소 분리
# df_old['pos_split'] = df_old['발화데이터'].apply(tagger.pos)

def pos_split(df:pd.DataFrame, col='speech'):
    i = -1
    for i in range(df.shape[0]//1000):      # 넘 많아~~
        df.loc[i*1000:(i+1)*1000, 'pos_split'] = df.loc[i*1000:(i+1)*1000, col].astype(str).apply(tagger.pos)
        print(f'{i*1000} ~ {(i+1)*1000} 완')
    df.loc[(i+1)*1000:, 'pos_split'] = df.loc[(i+1)*1000:, col].apply(tagger.pos)

# %%
pos_split(df_old, 'SENTENCE')
df_old.to_excel('data/Speech_old_pos.xlsx', index=False)
# Out:
# 0 ~ 1000 완
# 1000 ~ 2000 완
# 2000 ~ 3000 완
# 3000 ~ 4000 완
# 4000 ~ 5000 완
# 5000 ~ 6000 완
# 6000 ~ 7000 완
# 7000 ~ 8000 완
# 8000 ~ 9000 완
# 9000 ~ 10000 완
# 10000 ~ 11000 완
# 11000 ~ 12000 완
# 12000 ~ 13000 완
# 13000 ~ 14000 완
# 14000 ~ 15000 완
# 15000 ~ 16000 완
# 16000 ~ 17000 완
# 17000 ~ 18000 완
# 18000 ~ 19000 완
# 19000 ~ 20000 완
# 20000 ~ 21000 완
# 21000 ~ 22000 완
# 22000 ~ 23000 완
# 23000 ~ 24000 완
# 24000 ~ 25000 완
# 25000 ~ 26000 완
# 26000 ~ 27000 완
# 27000 ~ 28000 완
# 28000 ~ 29000 완
# 29000 ~ 30000 완
# 30000 ~ 31000 완
# 31000 ~ 32000 완
# 32000 ~ 33000 완
# 33000 ~ 34000 완
# 34000 ~ 35000 완
# 35000 ~ 36000 완
# 36000 ~ 37000 완
# 37000 ~ 38000 완
# 38000 ~ 39000 완
# 39000 ~ 40000 완
# 40000 ~ 41000 완
# 41000 ~ 42000 완
# 42000 ~ 43000 완
# 43000 ~ 44000 완
# 44000 ~ 45000 완
# 45000 ~ 46000 완
# 46000 ~ 47000 완
# 47000 ~ 48000 완
# 48000 ~ 49000 완
# 49000 ~ 50000 완
# 50000 ~ 51000 완
# 51000 ~ 52000 완
# 52000 ~ 53000 완
# 53000 ~ 54000 완
# 54000 ~ 55000 완

# %%
# df_old = pd.read_excel('data/Speech_old_pos.xlsx')
df_old.head()
# Out:
#        INTENT                   SENTENCE  \
# 0  100퍼센트충전안됨        배터리 아무리 해도 백이 되지 않음
# 1  100퍼센트충전안됨  배터리가 구십퍼 이상으로 충전이 되지 않습니다
# 2  100퍼센트충전안됨               백퍼로 충전이 안 돼요
# 3  100퍼센트충전안됨             오래 충전해도 완충 안 됨
# 4  100퍼센트충전안됨         배터리가 백퍼센트 충전이 안 돼요
#
#                                            pos_split
# 0  [(배터리, NNG), (아무리, MAG), (하, VV), (아도, EC), (백...
# 1  [(배터리, NNG), (가, JKS), (구십, NR), (퍼, NNB), (이상...
# 2  [(백, NR), (퍼, NNB), (로, JKB), (충전, NNG), (이, J...
# 3  [(오래, MAG), (충전하, VV), (아도, EC), (완충, NNG), (안...
# 4  [(배터리, NNG), (가, JKS), (백, NNG), (퍼센트, NNG), (...

# %%
def str_to_poslist(pos_str):
    pos_str = pos_str.strip('[]')
    pos_list = pos_str.split('), (')
    pos_list = [tuple(p.strip("()").replace("'", "").split(', ')) for p in pos_list]
    return pos_list

# %%
# df_old.pos_split = df_old.pos_split.apply(str_to_poslist)
# df_old.pos_split
# Out:
# 0        [(계속, MAG), (꽂, VV), (아, EC), (놓, VX), (고, EC)...
# 1        [(배터리, NNG), (아무리, MAG), (하, VV), (아도, EC), (백...
# 2        [(배터리, NNG), (완충, NNG), (이, JKS), (안, MAG), (되...
# 3        [(배터리, NNG), (가, JKS), (구십, NR), (퍼, NNB), (이상...
# 4        [(배터리, NNG), (가, JKS), (꽉, MAG), (차, VV), (지, ...
#                                ...
# 58712    [(필터, NNG), (를, JKO), (빼, VV), (는, ETM), (방법, ...
# 58713           [(썬더볼트, NNG), (지원되, VV), (나, EF), (요, JX)]
# 58714    [(썬더볼트, NNG), (지원되, VV), (는지, EC), (어떻, VA), (...
# 58715    [(저, NP), (의, JKG), (노트북, NNG), (썬더볼트, NNG), (...
# 58716    [(제, NP), (가, JKS), (쓰, VV), (는, ETM), (노트북, N...
# Name: pos_split, Length: 58717, dtype: object

# %%
df_old[df_old.pos_split.apply(lambda x:type(x)!=list)]
# Out:
# Empty DataFrame
# Columns: [INTENT, SENTENCE, pos_split]
# Index: []

# %%
pos_split(df_new, 'SENTENCE')

# %%
df_new[df_new.pos_split.apply(lambda x:type(x)!=list)]
# Out:
# Empty DataFrame
# Columns: [INTENT, SENTENCE, pos_split]
# Index: []

# %%
df_new.head()
# Out:
#        INTENT              SENTENCE  \
# 0       E1 에러          이원 버그 표시 뭐예요
# 1       E1 에러           이원에러 표시 떳어요
# 2  FdH표시_하칸제상     냉장고 에프 디 에이치 에러코드
# 3  FdH표시_하칸제상  냉장고 에프 디 에이치 오류가 있어요
# 4  FdH표시_하칸제상      냉장고 에프 디 에이치가 떠요
#
#                                            pos_split
# 0  [(이원, NNG), (버그, NNG), (표시, NNG), (뭐, NP), (이,...
# 1  [(이, MMD), (원, NNB), (에, JKG), (러, NNP), (표시, ...
# 2  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...
# 3  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...
# 4  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...

# %%
df_new.isna().sum(), df_old.isna().sum()
# Out:
# (INTENT       0
#  SENTENCE     0
#  pos_split    0
#  dtype: int64,
#  INTENT       0
#  SENTENCE     0
#  pos_split    0
#  dtype: int64)

# %%
# df_old = pd.concat([df_old, df_new.loc[df_new.EDIT=='추가', ['INTENT', 'SENTENCE', 'pos_split']]]).reset_index(drop=True)

# %%
# # 유사도 계산, 
# for i in range(df_new.shape[0]):
#     res = df_new.pos_split.apply(lambda x:jacaard_similarity(x, df_new.pos_split[i])).sort_values(ascending=False)[:3]
#     df_new.loc[i, ['idx1', 'idx2', 'idx3']] = res.index.to_list()
#     df_new.loc[i, ['sim_score1', 'sim_score2', 'sim_score3']] = res.values
# df_new.head()
# Out:
#        INTENT          SENTENCE  \
# 0  100퍼센트충전안됨  백퍼센트 충전이 되지 않습니다
# 1  100퍼센트충전안됨      백퍼센트 충전이 안돼요
# 2  100퍼센트충전안됨   백프로 충전이 되지 않습니다
# 3  100퍼센트충전안됨       백프로 충전이 안돼요
# 4  100퍼센트충전안됨    백퍼 충전이 되지 않습니다
#
#                                            pos_split  idx1    idx2    idx3  \
# 0  [(백, NNG), (퍼센트, NNG), (충전, NNG), (이, JKC), (되...   0.0  1179.0     4.0
# 1  [(백, NNG), (퍼센트, NNG), (충전, NNG), (이, JKS), (안...   1.0  2857.0   117.0
# 2  [(백, NR), (프로, NNB), (충전, NNG), (이, JKC), (되, ...   2.0     4.0  1179.0
# 3  [(백, NR), (프로, NNB), (충전, NNG), (이, JKS), (안, ...   3.0     5.0  1178.0
# 4  [(백, NR), (퍼, NNB), (충전, NNG), (이, JKC), (되, V...   4.0     2.0  1179.0
#
#    sim_score1  sim_score2  sim_score3
# 0         1.0    0.750000    0.600000
# 1         1.0    0.428571    0.428571
# 2         1.0    0.777778    0.750000
# 3         1.0    0.750000    0.714286
# 4         1.0    0.777778    0.750000

# %%
# 유사도 계산, 
for i in range(df_new.shape[0]):
    res = df_old.pos_split.apply(lambda x:jacaard_similarity(x, df_new.pos_split[i])).sort_values(ascending=False)[:3]
    df_new.loc[i, ['idx1', 'idx2', 'idx3']] = res.index.to_list()
    df_new.loc[i, ['sim_score1', 'sim_score2', 'sim_score3']] = res.values
df_new.head()
# Out:
#        INTENT              SENTENCE  \
# 0       E1 에러          이원 버그 표시 뭐예요
# 1       E1 에러           이원에러 표시 떳어요
# 2  FdH표시_하칸제상     냉장고 에프 디 에이치 에러코드
# 3  FdH표시_하칸제상  냉장고 에프 디 에이치 오류가 있어요
# 4  FdH표시_하칸제상      냉장고 에프 디 에이치가 떠요
#
#                                            pos_split     idx1     idx2  \
# 0  [(이원, NNG), (버그, NNG), (표시, NNG), (뭐, NP), (이,...   4215.0   8177.0
# 1  [(이, MMD), (원, NNB), (에, JKG), (러, NNP), (표시, ...   2300.0  43610.0
# 2  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   4541.0   2808.0
# 3  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...  19215.0  47282.0
# 4  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   2543.0  43647.0
#
#       idx3  sim_score1  sim_score2  sim_score3
# 0   2512.0    0.500000    0.444444    0.400000
# 1   2696.0    0.375000    0.300000    0.272727
# 2   2569.0    0.333333    0.333333    0.285714
# 3  48959.0    0.333333    0.333333    0.333333
# 4   2856.0    0.500000    0.444444    0.444444

# %%
# 한건만 확인
test = tagger.pos('가습기 분해 청소도 해주나요')
sml = df_old.pos_split.apply(lambda x:jacaard_similarity(x, test)).sort_values(ascending=False)[:3]
print(sml)
df_old.loc[sml.index, ]
# Out:
# 5807    1.000000
# 6075    0.583333
# 6083    0.538462
# Name: pos_split, dtype: float64
#        INTENT          SENTENCE  \
# 5807  가전세척서비스   가습기 분해 청소도 해주나요
# 6075  가전세척서비스   통 분리해서 청소도 해주나요
# 6083  가전세척서비스  통 분해해서 청소도 해주시나요
#
#                                               pos_split
# 5807  [(가습기, NNG), (분해, NNG), (청소, NNG), (도, JX), (하...
# 6075  [(통, MAG), (분리하, VV), (아서, EC), (청소, NNG), (도,...
# 6083  [(통, MAG), (분해하, VV), (아서, EC), (청소, NNG), (도,...

# %%
# for i in range(df_new.shape[0]):
#     df_new.loc[i, ['stc1', 'stc2', 'stc3']] = df_new.loc[df_new.loc[i, ['idx1', 'idx2', 'idx3']], 'SENTENCE'].values
#     df_new.loc[i, ['itt1', 'itt2', 'itt3']] = df_new.loc[df_new.loc[i, ['idx1', 'idx2', 'idx3']], 'INTENT'].values

#     # 다른 원소 찾아주는 거
#     poset = set(df_new.loc[i, 'pos_split'])
#     chaset = lambda x, p: str(set(x).union(p) - set(x).intersection(p))
#     df_new.loc[i, ['diff1', 'diff2', 'diff3']] = df_new.loc[df_new.loc[i, ['idx1', 'idx2', 'idx3']], 'pos_split'].apply(lambda x:chaset(x, poset)).values
# df_new.head()
# Out:
#        INTENT          SENTENCE  \
# 0  100퍼센트충전안됨  백퍼센트 충전이 되지 않습니다
# 1  100퍼센트충전안됨      백퍼센트 충전이 안돼요
# 2  100퍼센트충전안됨   백프로 충전이 되지 않습니다
# 3  100퍼센트충전안됨       백프로 충전이 안돼요
# 4  100퍼센트충전안됨    백퍼 충전이 되지 않습니다
#
#                                            pos_split  idx1    idx2    idx3  \
# 0  [(백, NNG), (퍼센트, NNG), (충전, NNG), (이, JKC), (되...   0.0  1179.0     4.0
# 1  [(백, NNG), (퍼센트, NNG), (충전, NNG), (이, JKS), (안...   1.0  2857.0   117.0
# 2  [(백, NR), (프로, NNB), (충전, NNG), (이, JKC), (되, ...   2.0     4.0  1179.0
# 3  [(백, NR), (프로, NNB), (충전, NNG), (이, JKS), (안, ...   3.0     5.0  1178.0
# 4  [(백, NR), (퍼, NNB), (충전, NNG), (이, JKC), (되, V...   4.0     2.0  1179.0
#
#    sim_score1  sim_score2  sim_score3              stc1             stc2  \
# 0         1.0    0.750000    0.600000  백퍼센트 충전이 되지 않습니다      충전이 되지 않습니다
# 1         1.0    0.428571    0.428571      백퍼센트 충전이 안돼요         미러링이 안돼요
# 2         1.0    0.777778    0.750000   백프로 충전이 되지 않습니다   백퍼 충전이 되지 않습니다
# 3         1.0    0.750000    0.714286       백프로 충전이 안돼요       백퍼 충전이 안돼요
# 4         1.0    0.777778    0.750000    백퍼 충전이 되지 않습니다  백프로 충전이 되지 않습니다
#
#              stc3        itt1          itt2          itt3  diff1  \
# 0  백퍼 충전이 되지 않습니다  100퍼센트충전안됨  충전안됨_충전램프깜박임    100퍼센트충전안됨  set()
# 1         출력이 안돼요  100퍼센트충전안됨       미라캐스트연결       가열_출력안됨  set()
# 2     충전이 되지 않습니다  100퍼센트충전안됨    100퍼센트충전안됨  충전안됨_충전램프깜박임  set()
# 3         충전이 안돼요  100퍼센트충전안됨    100퍼센트충전안됨  충전안됨_충전램프깜박임  set()
# 4     충전이 되지 않습니다  100퍼센트충전안됨    100퍼센트충전안됨  충전안됨_충전램프깜박임  set()
#
#                                                diff2  \
# 0                     {('퍼센트', 'NNG'), ('백', 'NNG')}
# 1  {('퍼센트', 'NNG'), ('충전', 'NNG'), ('미러링', 'NNG')...
# 2                      {('프로', 'NNB'), ('퍼', 'NNB')}
# 3                      {('프로', 'NNB'), ('퍼', 'NNB')}
# 4                      {('프로', 'NNB'), ('퍼', 'NNB')}
#
#                                                diff3
# 0  {('퍼센트', 'NNG'), ('백', 'NR'), ('퍼', 'NNB'), ('...
# 1  {('퍼센트', 'NNG'), ('충전', 'NNG'), ('출력', 'NNG'),...
# 2                       {('프로', 'NNB'), ('백', 'NR')}
# 3                       {('프로', 'NNB'), ('백', 'NR')}
# 4                        {('퍼', 'NNB'), ('백', 'NR')}

# %%
for i in range(df_new.shape[0]):
    df_new.loc[i, ['stc1', 'stc2', 'stc3']] = df_old.loc[df_new.loc[i, ['idx1', 'idx2', 'idx3']], 'SENTENCE'].values
    df_new.loc[i, ['itt1', 'itt2', 'itt3']] = df_old.loc[df_new.loc[i, ['idx1', 'idx2', 'idx3']], 'INTENT'].values

    # 다른 원소 찾아주는 거
    poset = set(df_new.loc[i, 'pos_split'])
    chaset = lambda x, p: str(set(x).union(p) - set(x).intersection(p))
    df_new.loc[i, ['diff1', 'diff2', 'diff3']] = df_old.loc[df_new.loc[i, ['idx1', 'idx2', 'idx3']], 'pos_split'].apply(lambda x:chaset(x, poset)).values
df_new.head()
# Out:
#        INTENT              SENTENCE  \
# 0       E1 에러          이원 버그 표시 뭐예요
# 1       E1 에러           이원에러 표시 떳어요
# 2  FdH표시_하칸제상     냉장고 에프 디 에이치 에러코드
# 3  FdH표시_하칸제상  냉장고 에프 디 에이치 오류가 있어요
# 4  FdH표시_하칸제상      냉장고 에프 디 에이치가 떠요
#
#                                            pos_split     idx1     idx2  \
# 0  [(이원, NNG), (버그, NNG), (표시, NNG), (뭐, NP), (이,...   4215.0   8177.0
# 1  [(이, MMD), (원, NNB), (에, JKG), (러, NNP), (표시, ...   2300.0  43610.0
# 2  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   4541.0   2808.0
# 3  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...  19215.0  47282.0
# 4  [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   2543.0  43647.0
#
#       idx3  sim_score1  sim_score2  sim_score3                stc1  \
# 0   2512.0    0.500000    0.444444    0.400000         엔에프 표시가 뭐에요
# 1   2696.0    0.375000    0.300000    0.272727           온도창에 이 표시
# 2   2569.0    0.333333    0.333333    0.285714           에러코드 오 에프
# 3  48959.0    0.333333    0.333333    0.333333  동영상 재생 설정에 오류가 있어요
# 4   2856.0    0.500000    0.444444    0.444444           에프 표시가 떠요
#
#             stc2               stc3        itt1          itt2         itt3  \
# 0  기역 니은 표시가 뭐에요   이알 에프원 표시 이거 뭐에요        nF표시    ㄱ_ㄴ표시_바람방향   ErF1_EF1표시
# 1    이 영일 표시가 떠요  이 에러 표시가 디스플레이에 뜸  EAd_ErAd표시  점검코드_E_00_14  E에러_E2_578b
# 2   에러코드 에프 디에이치       에러코드 에이치원 의미        OF표시     FdH_rdH표시   ErH1_EH1표시
# 3        벌레가 있어요            악취가 있어요   동영상재생오류설정         청소_통합     퀴퀴한곰팡이냄새
# 4    에프 십 표시가 떠요         에프이 에러가 떠요  ErFF_EFF표시   점검코드_F_1_19    FE표시_급수밸브
#
#                                                diff1  \
# 0  {('버그', 'NNG'), ('이원', 'NNG'), ('가', 'JKS'), (...
# 1  {('떳', 'VV'), ('원', 'NNB'), ('온도창', 'NNG'), ('...
# 2  {('에이치', 'NNG'), ('냉장고', 'NNG'), ('디', 'NNG'),...
# 3  {('에이치', 'NNG'), ('에프', 'NNG'), ('디', 'NNG'), ...
# 4  {('에이치', 'NNG'), ('표시', 'NNG'), ('냉장고', 'NNG')...
#
#                                                diff2  \
# 0  {('버그', 'NNG'), ('가', 'JKS'), ('니은', 'NNG'), (...
# 1  {('에', 'JKG'), ('원', 'NNB'), ('떳', 'VV'), ('가'...
# 2  {('에이치', 'NNG'), ('냉장고', 'NNG'), ('디', 'NNG'),...
# 3  {('에이치', 'NNG'), ('벌레', 'NNG'), ('에프', 'NNG'),...
# 4  {('에이치', 'NNG'), ('십', 'NR'), ('표시', 'NNG'), (...
#
#                                                diff3
# 0  {('원', 'NNG'), ('이알', 'NNG'), ('버그', 'NNG'), (...
# 1  {('뜸', 'NNG'), ('원', 'NNB'), ('떳', 'VV'), ('가'...
# 2  {('원', 'NNG'), ('에프', 'NNG'), ('디', 'NNG'), ('...
# 3  {('에이치', 'NNG'), ('악취', 'NNG'), ('에프', 'NNG'),...
# 4  {('에이치', 'NNG'), ('이', 'JKS'), ('에러', 'NNG'), ...

# %%
df_new
# Out:
#          INTENT                SENTENCE  \
# 0         E1 에러            이원 버그 표시 뭐예요
# 1         E1 에러             이원에러 표시 떳어요
# 2    FdH표시_하칸제상       냉장고 에프 디 에이치 에러코드
# 3    FdH표시_하칸제상    냉장고 에프 디 에이치 오류가 있어요
# 4    FdH표시_하칸제상        냉장고 에프 디 에이치가 떠요
# ..          ...                     ...
# 672      필터청소교체     어플에 에어컨 청소 권장이 뜨는데요
# 673      필터청소교체    어플에 에어컨 청소 권장이라고 나와요
# 674      필터청소교체  에어컨 청소 권장이 뜨면 청소해야 하나요
# 675      필터청소교체     에어컨 청소 권장이 왜 뜨는 건가요
# 676      필터청소교체            에어컨 청소 권장한대요
#
#                                              pos_split     idx1     idx2  \
# 0    [(이원, NNG), (버그, NNG), (표시, NNG), (뭐, NP), (이,...   4215.0   8177.0
# 1    [(이, MMD), (원, NNB), (에, JKG), (러, NNP), (표시, ...   2300.0  43610.0
# 2    [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   4541.0   2808.0
# 3    [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...  19215.0  47282.0
# 4    [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   2543.0  43647.0
# ..                                                 ...      ...      ...
# 672  [(어플, NNP), (에, JKB), (에어컨, NNG), (청소, NNG), (...  41235.0  35721.0
# 673  [(어플, NNP), (에, JKB), (에어컨, NNG), (청소, NNG), (...   7454.0   1305.0
# 674  [(에어컨, NNG), (청소, NNG), (권장, NNG), (이, JKS), (...  50680.0  50682.0
# 675  [(에어컨, NNG), (청소, NNG), (권장, NNG), (이, JKS), (...   4019.0   3647.0
# 676  [(에어컨, NNG), (청소, NNG), (권장하, VV), (ㄴ대, EF), (...  47173.0  47291.0
#
#         idx3  sim_score1  sim_score2  sim_score3                      stc1  \
# 0     2512.0    0.500000    0.444444    0.400000               엔에프 표시가 뭐에요
# 1     2696.0    0.375000    0.300000    0.272727                 온도창에 이 표시
# 2     2569.0    0.333333    0.333333    0.285714                 에러코드 오 에프
# 3    48959.0    0.333333    0.333333    0.333333        동영상 재생 설정에 오류가 있어요
# 4     2856.0    0.500000    0.444444    0.444444                 에프 표시가 떠요
# ..       ...         ...         ...         ...                       ...
# 672   1869.0    0.416667    0.416667    0.357143           화면 중앙에 자막이 뜨는데요
# 673   2815.0    0.416667    0.416667    0.416667             표시창에 유이라고 나와요
# 674  28888.0    0.437500    0.437500    0.411765  천정형 에어컨 팬이 파손되면 교체해야 하나요
# 675   1172.0    0.538462    0.500000    0.470588              엘오는 왜 뜨는 건가요
# 676  46892.0    0.400000    0.375000    0.333333                    에어컨 청소
#
#                             stc2                            stc3         itt1  \
# 0                  기역 니은 표시가 뭐에요                이알 에프원 표시 이거 뭐에요         nF표시
# 1                    이 영일 표시가 떠요               이 에러 표시가 디스플레이에 뜸   EAd_ErAd표시
# 2                   에러코드 에프 디에이치                    에러코드 에이치원 의미         OF표시
# 3                        벌레가 있어요                         악취가 있어요    동영상재생오류설정
# 4                    에프 십 표시가 떠요                      에프이 에러가 떠요   ErFF_EFF표시
# ..                           ...                             ...          ...
# 672               에어컨에 얼음이 생겼는데요              에어컨 표시창에 씨엘이 왜 뜰까요     자막방송설정방법
# 673        에어컨에서 씨에이치 삼십팔이라고 나와요                냉장온도에 디에이치라고 나와요     UE표시_불균형
# 674  투인원 에어컨 팬이 부러지면 바로 교체해야 하나요        섬유 유연제 알림이 뜨면 어떻게 해야 하나요          팬파손
# 675             엘이 뜨는 게 무슨 에러인가요  에어컨에서 갑자기 씨에이치 삼팔 표시가 왜 뜨는 건가요  LO표시_실내온도낮음
# 676            청소가 에어컨 청소가 가능한가요                       에어컨 필터 청소        청소_통합
#
#              itt2          itt3  \
# 0      ㄱ_ㄴ표시_바람방향    ErF1_EF1표시
# 1    점검코드_E_00_14   E에러_E2_578b
# 2       FdH_rdH표시    ErH1_EH1표시
# 3           청소_통합      퀴퀴한곰팡이냄새
# 4     점검코드_F_1_19     FE표시_급수밸브
# ..            ...           ...
# 672       여름냉방_통합       CL표시_통합
# 673  CH54번표시_입력전원     FdH_rdH표시
# 674           팬파손       섬유유연제알림
# 675       LE표시_통합  CH38번표시_냉매부족
# 676         청소_통합         청소_통합
#
#                                                  diff1  \
# 0    {('버그', 'NNG'), ('이원', 'NNG'), ('가', 'JKS'), (...
# 1    {('떳', 'VV'), ('원', 'NNB'), ('온도창', 'NNG'), ('...
# 2    {('에이치', 'NNG'), ('냉장고', 'NNG'), ('디', 'NNG'),...
# 3    {('에이치', 'NNG'), ('에프', 'NNG'), ('디', 'NNG'), ...
# 4    {('에이치', 'NNG'), ('표시', 'NNG'), ('냉장고', 'NNG')...
# ..                                                 ...
# 672  {('어플', 'NNP'), ('자막', 'NNG'), ('에어컨', 'NNG'),...
# 673  {('어플', 'NNP'), ('유', 'NNG'), ('표시', 'NNG'), (...
# 674  {('천정', 'NNG'), ('팬', 'NNG'), ('파손되', 'VV'), (...
# 675  {('이', 'JKS'), ('는', 'JX'), ('에어컨', 'NNG'), ('...
# 676         {('요', 'JX'), ('ㄴ대', 'EF'), ('권장하', 'VV')}
#
#                                                  diff2  \
# 0    {('버그', 'NNG'), ('가', 'JKS'), ('니은', 'NNG'), (...
# 1    {('에', 'JKG'), ('원', 'NNB'), ('떳', 'VV'), ('가'...
# 2    {('에이치', 'NNG'), ('냉장고', 'NNG'), ('디', 'NNG'),...
# 3    {('에이치', 'NNG'), ('벌레', 'NNG'), ('에프', 'NNG'),...
# 4    {('에이치', 'NNG'), ('십', 'NR'), ('표시', 'NNG'), (...
# ..                                                 ...
# 672  {('어플', 'NNP'), ('었', 'EP'), ('생기', 'VV'), ('청...
# 673  {('어플', 'NNP'), ('씨에이치', 'NNG'), ('권장', 'NNG')...
# 674  {('투인원', 'NNG'), ('팬', 'NNG'), ('권장', 'NNG'), ...
# 675  {('무슨', 'MMD'), ('엘', 'NNG'), ('왜', 'MAG'), ('...
# 676  {('가', 'JKS'), ('권장하', 'VV'), ('가능하', 'VA'), (...
#
#                                                  diff3
# 0    {('원', 'NNG'), ('이알', 'NNG'), ('버그', 'NNG'), (...
# 1    {('뜸', 'NNG'), ('원', 'NNB'), ('떳', 'VV'), ('가'...
# 2    {('원', 'NNG'), ('에프', 'NNG'), ('디', 'NNG'), ('...
# 3    {('에이치', 'NNG'), ('악취', 'NNG'), ('에프', 'NNG'),...
# 4    {('에이치', 'NNG'), ('이', 'JKS'), ('에러', 'NNG'), ...
# ..                                                 ...
# 672  {('어플', 'NNP'), ('왜', 'MAG'), ('표시', 'NNG'), (...
# 673  {('어플', 'NNP'), ('온도', 'NNG'), ('냉장', 'NNG'), ...
# 674  {('섬유', 'NNG'), ('유연제', 'NNG'), ('에어컨', 'NNG')...
# 675  {('이', 'JKS'), ('가', 'JKS'), ('표시', 'NNG'), ('...
# 676  {('요', 'JX'), ('ㄴ대', 'EF'), ('권장하', 'VV'), ('필...
#
# [677 rows x 18 columns]

# %%
df_old
# Out:
#             INTENT                        SENTENCE  \
# 0       100퍼센트충전안됨             배터리 아무리 해도 백이 되지 않음
# 1       100퍼센트충전안됨       배터리가 구십퍼 이상으로 충전이 되지 않습니다
# 2       100퍼센트충전안됨                    백퍼로 충전이 안 돼요
# 3       100퍼센트충전안됨                  오래 충전해도 완충 안 됨
# 4       100퍼센트충전안됨              배터리가 백퍼센트 충전이 안 돼요
# ...            ...                             ...
# 55525  희망온도에실외기안꺼짐           설정한 온도인데 실외기가 계속 돌아가요
# 55526  희망온도에실외기안꺼짐       설정 온도에 도달했는데 실외기가 꺼지지 않아요
# 55527  희망온도에실외기안꺼짐          희망온도 됐는데 실외기가 계속 돌아갑니다
# 55528  희망온도에실외기안꺼짐  설정한 온도에 도달했는데 실외기가 계속 돌아가고 있어요
# 55529  희망온도에실외기안꺼짐         설정 온도에 맞춰도 실외기가 꺼지지 않는데
#
#                                                pos_split
# 0      [(배터리, NNG), (아무리, MAG), (하, VV), (아도, EC), (백...
# 1      [(배터리, NNG), (가, JKS), (구십, NR), (퍼, NNB), (이상...
# 2      [(백, NR), (퍼, NNB), (로, JKB), (충전, NNG), (이, J...
# 3      [(오래, MAG), (충전하, VV), (아도, EC), (완충, NNG), (안...
# 4      [(배터리, NNG), (가, JKS), (백, NNG), (퍼센트, NNG), (...
# ...                                                  ...
# 55525  [(설정하, VV), (ㄴ, ETM), (온도, NNG), (이, VCP), (ㄴ데...
# 55526  [(설정, NNG), (온도, NNG), (에, JKB), (도달하, VV), (았...
# 55527  [(희망, NNG), (온도, NNG), (되, VV), (었, EP), (는데, ...
# 55528  [(설정하, VV), (ㄴ, ETM), (온도, NNG), (에, JKB), (도달...
# 55529  [(설정, NNG), (온도, NNG), (에, JKB), (맞추, VV), (어도...
#
# [55530 rows x 3 columns]

# %%
df_new
# Out:
#          INTENT                SENTENCE  \
# 0         E1 에러            이원 버그 표시 뭐예요
# 1         E1 에러             이원에러 표시 떳어요
# 2    FdH표시_하칸제상       냉장고 에프 디 에이치 에러코드
# 3    FdH표시_하칸제상    냉장고 에프 디 에이치 오류가 있어요
# 4    FdH표시_하칸제상        냉장고 에프 디 에이치가 떠요
# ..          ...                     ...
# 672      필터청소교체     어플에 에어컨 청소 권장이 뜨는데요
# 673      필터청소교체    어플에 에어컨 청소 권장이라고 나와요
# 674      필터청소교체  에어컨 청소 권장이 뜨면 청소해야 하나요
# 675      필터청소교체     에어컨 청소 권장이 왜 뜨는 건가요
# 676      필터청소교체            에어컨 청소 권장한대요
#
#                                              pos_split     idx1     idx2  \
# 0    [(이원, NNG), (버그, NNG), (표시, NNG), (뭐, NP), (이,...   4215.0   8177.0
# 1    [(이, MMD), (원, NNB), (에, JKG), (러, NNP), (표시, ...   2300.0  43610.0
# 2    [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   4541.0   2808.0
# 3    [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...  19215.0  47282.0
# 4    [(냉장고, NNG), (에프, NNG), (디, NNG), (에이치, NNG), ...   2543.0  43647.0
# ..                                                 ...      ...      ...
# 672  [(어플, NNP), (에, JKB), (에어컨, NNG), (청소, NNG), (...  41235.0  35721.0
# 673  [(어플, NNP), (에, JKB), (에어컨, NNG), (청소, NNG), (...   7454.0   1305.0
# 674  [(에어컨, NNG), (청소, NNG), (권장, NNG), (이, JKS), (...  50680.0  50682.0
# 675  [(에어컨, NNG), (청소, NNG), (권장, NNG), (이, JKS), (...   4019.0   3647.0
# 676  [(에어컨, NNG), (청소, NNG), (권장하, VV), (ㄴ대, EF), (...  47173.0  47291.0
#
#         idx3  sim_score1  sim_score2  sim_score3                      stc1  \
# 0     2512.0    0.500000    0.444444    0.400000               엔에프 표시가 뭐에요
# 1     2696.0    0.375000    0.300000    0.272727                 온도창에 이 표시
# 2     2569.0    0.333333    0.333333    0.285714                 에러코드 오 에프
# 3    48959.0    0.333333    0.333333    0.333333        동영상 재생 설정에 오류가 있어요
# 4     2856.0    0.500000    0.444444    0.444444                 에프 표시가 떠요
# ..       ...         ...         ...         ...                       ...
# 672   1869.0    0.416667    0.416667    0.357143           화면 중앙에 자막이 뜨는데요
# 673   2815.0    0.416667    0.416667    0.416667             표시창에 유이라고 나와요
# 674  28888.0    0.437500    0.437500    0.411765  천정형 에어컨 팬이 파손되면 교체해야 하나요
# 675   1172.0    0.538462    0.500000    0.470588              엘오는 왜 뜨는 건가요
# 676  46892.0    0.400000    0.375000    0.333333                    에어컨 청소
#
#                             stc2                            stc3         itt1  \
# 0                  기역 니은 표시가 뭐에요                이알 에프원 표시 이거 뭐에요         nF표시
# 1                    이 영일 표시가 떠요               이 에러 표시가 디스플레이에 뜸   EAd_ErAd표시
# 2                   에러코드 에프 디에이치                    에러코드 에이치원 의미         OF표시
# 3                        벌레가 있어요                         악취가 있어요    동영상재생오류설정
# 4                    에프 십 표시가 떠요                      에프이 에러가 떠요   ErFF_EFF표시
# ..                           ...                             ...          ...
# 672               에어컨에 얼음이 생겼는데요              에어컨 표시창에 씨엘이 왜 뜰까요     자막방송설정방법
# 673        에어컨에서 씨에이치 삼십팔이라고 나와요                냉장온도에 디에이치라고 나와요     UE표시_불균형
# 674  투인원 에어컨 팬이 부러지면 바로 교체해야 하나요        섬유 유연제 알림이 뜨면 어떻게 해야 하나요          팬파손
# 675             엘이 뜨는 게 무슨 에러인가요  에어컨에서 갑자기 씨에이치 삼팔 표시가 왜 뜨는 건가요  LO표시_실내온도낮음
# 676            청소가 에어컨 청소가 가능한가요                       에어컨 필터 청소        청소_통합
#
#              itt2          itt3  \
# 0      ㄱ_ㄴ표시_바람방향    ErF1_EF1표시
# 1    점검코드_E_00_14   E에러_E2_578b
# 2       FdH_rdH표시    ErH1_EH1표시
# 3           청소_통합      퀴퀴한곰팡이냄새
# 4     점검코드_F_1_19     FE표시_급수밸브
# ..            ...           ...
# 672       여름냉방_통합       CL표시_통합
# 673  CH54번표시_입력전원     FdH_rdH표시
# 674           팬파손       섬유유연제알림
# 675       LE표시_통합  CH38번표시_냉매부족
# 676         청소_통합         청소_통합
#
#                                                  diff1  \
# 0    {('버그', 'NNG'), ('이원', 'NNG'), ('가', 'JKS'), (...
# 1    {('떳', 'VV'), ('원', 'NNB'), ('온도창', 'NNG'), ('...
# 2    {('에이치', 'NNG'), ('냉장고', 'NNG'), ('디', 'NNG'),...
# 3    {('에이치', 'NNG'), ('에프', 'NNG'), ('디', 'NNG'), ...
# 4    {('에이치', 'NNG'), ('표시', 'NNG'), ('냉장고', 'NNG')...
# ..                                                 ...
# 672  {('어플', 'NNP'), ('자막', 'NNG'), ('에어컨', 'NNG'),...
# 673  {('어플', 'NNP'), ('유', 'NNG'), ('표시', 'NNG'), (...
# 674  {('천정', 'NNG'), ('팬', 'NNG'), ('파손되', 'VV'), (...
# 675  {('이', 'JKS'), ('는', 'JX'), ('에어컨', 'NNG'), ('...
# 676         {('요', 'JX'), ('ㄴ대', 'EF'), ('권장하', 'VV')}
#
#                                                  diff2  \
# 0    {('버그', 'NNG'), ('가', 'JKS'), ('니은', 'NNG'), (...
# 1    {('에', 'JKG'), ('원', 'NNB'), ('떳', 'VV'), ('가'...
# 2    {('에이치', 'NNG'), ('냉장고', 'NNG'), ('디', 'NNG'),...
# 3    {('에이치', 'NNG'), ('벌레', 'NNG'), ('에프', 'NNG'),...
# 4    {('에이치', 'NNG'), ('십', 'NR'), ('표시', 'NNG'), (...
# ..                                                 ...
# 672  {('어플', 'NNP'), ('었', 'EP'), ('생기', 'VV'), ('청...
# 673  {('어플', 'NNP'), ('씨에이치', 'NNG'), ('권장', 'NNG')...
# 674  {('투인원', 'NNG'), ('팬', 'NNG'), ('권장', 'NNG'), ...
# 675  {('무슨', 'MMD'), ('엘', 'NNG'), ('왜', 'MAG'), ('...
# 676  {('가', 'JKS'), ('권장하', 'VV'), ('가능하', 'VA'), (...
#
#                                                  diff3
# 0    {('원', 'NNG'), ('이알', 'NNG'), ('버그', 'NNG'), (...
# 1    {('뜸', 'NNG'), ('원', 'NNB'), ('떳', 'VV'), ('가'...
# 2    {('원', 'NNG'), ('에프', 'NNG'), ('디', 'NNG'), ('...
# 3    {('에이치', 'NNG'), ('악취', 'NNG'), ('에프', 'NNG'),...
# 4    {('에이치', 'NNG'), ('이', 'JKS'), ('에러', 'NNG'), ...
# ..                                                 ...
# 672  {('어플', 'NNP'), ('왜', 'MAG'), ('표시', 'NNG'), (...
# 673  {('어플', 'NNP'), ('온도', 'NNG'), ('냉장', 'NNG'), ...
# 674  {('섬유', 'NNG'), ('유연제', 'NNG'), ('에어컨', 'NNG')...
# 675  {('이', 'JKS'), ('가', 'JKS'), ('표시', 'NNG'), ('...
# 676  {('요', 'JX'), ('ㄴ대', 'EF'), ('권장하', 'VV'), ('필...
#
# [677 rows x 18 columns]

# %%
df_new.to_excel('result/speech_setence_similarity.xlsx', index=False)

# %%
word_part = {
    'NNG': '일반 명사',	
    'NNP': '고유 명사',	
    'NNB': '의존 명사',	
    'NP': '대명사',	
    'NR': '수사',	
    'VV': '동사',	
    'VA': '형용사',	
    'VX': '보조 용언',
    'MMA': '성상 관형사',	
    'MMD': '지시 관형사',	
    'MMN': '수 관형사',	
    'MAG': '일반 부사',	
    'MAJ': '접속 부사',	
    'IC': '감탄사', 
    'XPN': '체언 접두사', 
    'XSN': '명사 파생 접미사',	
    'XSV': '동사 파생 접미사',	
    'XSA': '형용사 파생 접미사',	
    'XR': '어근',	
    'SL': '외국어', 
    'NF': '명사 추정 범주',
    'NA': ' 분석불능범주',
    'NV': '용언 추정 범주'
}

# not_word = {
#     긍정 지정사	VCP
#     부정 지정사	VCN
#     주격 조사	JKS
#     보격 조사	JKC
#     관형격 조사	JKG
#     목적격 조사	JKO
#     부사격 조사	JKB
#     호격 조사	JKV
#     인용격 조사	JKQ
#     보조사	JX
#     접속 조사	JC
#     선어말 어미	EP
#     종결 어미	EF
#     연결 어미	EC
#     명사형 전성 어미	ETN
#     관형형 전성 어미	ETM
#     마침표, 물음표, 느낌표	SF
#     쉼표, 가운뎃점, 콜론, 빗금	SP
#     따옴표, 괄호표, 줄표	SS
#     줄임표	SE
#     붙임표(물결, 숨김, 빠짐)	SO
#     기타기호 (논리수학기호, 화폐기호)	SW
#     한자	SH
#     숫자	SN
# }

# %%
df.shape

# %%
df.speech_nospace[:200].apply(lambda s:[t[0] for t in tagger.pos(s) if t[1] in word_part.keys()])

# %%
# df['morphemes'] = df.speech_data.apply(lambda s:[t[0] for t in tagger.pos(s) if t[1] in word_part.keys()])

# %%
df.to_csv('result/241203_allprd_data_형태소분리(띄어쓰기).csv', encoding='ansi')

# %%
from collections import Counter

mCnt = Counter()

for mm in df.morphemes:
    mCnt += Counter(mm)

# %%
df.dropna(subset='SYMP_NAME_THREE', inplace=True)

# %%
df.SYMP_NAME_THREE.isna().sum()

# %%
df_cnt = df.drop(columns=['PRODUCT_GROUP_NAME', 'SYMP_CODE_ONE', 'SYMP_CODE_TWO', 'SYMP_CODE_THREE', 'speech_data']).explode('morphemes')

# %%
df_cnt['cnt'] = 1

# %%
df_cnt

# %%
df_cnt_pv = df_cnt.pivot_table(index=['PRODUCT_NAME', 'SYMP_NAME_THREE'], columns='morphemes', values='cnt', aggfunc='sum')
df_cnt_pv

# %%
mcnt = df_cnt_pv.sum()
scnt = df_cnt_pv.sum(axis=1)

# %%
df_cnt_pv.fillna(0, inplace=True)

# %%
df_cnt_pv

# %%
df_prob_pv = df_cnt_pv.copy()
df_prob_pv = df_prob_pv.div(mcnt, axis=1) * 203200

# %%
df_prob_pv

# %%
for p,s in scnt.index:
    df_prob_pv.loc[p,s] /= scnt[p,s]

# %%
df_cnt_pv['고장']['2in1', 'CH 38번 표시 [냉매 부족]']

# %%
mcnt['고장'], scnt['2in1', 'CH 38번 표시 [냉매 부족]']

# %%
np.log2(9/351/615*203200)

# %%
import numpy as np

# %%
df_prob_pv = np.log2(df_prob_pv)

# %%
df_prob_pv = np.maximum(df_prob_pv, 0)

# %%
df_prob_pv.to_csv('result/pmi.csv', encoding='ansi')

# %%
df[df.morphemes.apply(lambda x:'심하' in x)]
